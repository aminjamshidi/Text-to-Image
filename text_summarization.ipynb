# %% [markdown]
# #Data Cleaning

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install langdetect

# %%
import re
import nltk
import pandas as pd
#from langdetect import detect, DetectorFactory
from nltk.tokenize import sent_tokenize, word_tokenize
nltk.download('punkt')
#import langdetect
import math
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
#read .txt file and convert it to dataframe
file_path='/content/drive/MyDrive/booksummaries.txt'
fields=['ID', 'Tag', 'Title', 'Author', 'Year', 'Genre', 'Description']
data_frame = pd.read_csv(file_path, sep='\t', header=None, names=fields)

# %%
#cleaning data frame from missing value:
data_frame_cleaned = data_frame.dropna(axis=1)
#remove some Description that has small number of characters and their Description is missing
data_frame_cleaned['len_of_Description']=data_frame_cleaned['Description'].apply(len)
data_frame_cleaned=data_frame_cleaned[data_frame_cleaned['len_of_Description']>250]
#sort Description baseed on len_of_Description parameter
data_frame_cleaned=data_frame_cleaned.sort_values(by=['len_of_Description'], ascending=True)
# Out:
# <ipython-input-31-04e103ad82f2>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_frame_cleaned['len_of_Description']=data_frame_cleaned['Description'].apply(len)

# %%
#Define some function for preprocessing the text
# Set seed to make results reproducible
#DetectorFactory.seed = 0

# def detect_language(text):
#     try:
#         return langdetect.detect(text)
#     except langdetect.lang_detect_exception.LangDetectException:
#         return None

# def find_non_english_sentences(text):
#     sentences = sent_tokenize(text)
#     non_english_sentences = [sentence for sentence in sentences if detect_language(sentence) != 'en']
#     flag=True if len(non_english_sentences)!=0 else False
#     return flag,non_english_sentences


def preprocess_text(text):
  # remove urls
  url_pattern = r'https?://\S+|www\.\S+'
  text = re.sub(url_pattern, '', text)

  # flag,non_english_sentences=find_non_english_sentences(text)
  # if flag:
  #   for non_english_sentence in non_english_sentences:
  #     text=re.sub(non_english_sentence,'',text)

  #remove special characters ---> ===
  text=re.sub(r'===','',text)

  return text

# %%
data_frame_cleaned['clean_Description']=data_frame_cleaned['Description'].apply(preprocess_text)

# %%
data_frame_cleaned.head()
# Out:
#              ID         Tag                  Title  \
# 6549    5408961   /m/0dkk4_                 Zamper
# 13243  20297155  /m/04zxt3s      Blackthorn Winter
# 10895  13733151  /m/03cgkpf                Rebekah
# 12925  19433109  /m/04n2tm1  Vaporetto 13: A Novel
# 13221  20258594  /m/04zwxmp   Death of an Outsider
#
#                                              Description  len_of_Description  \
# 6549    The Doctor and his companions, separated from...                 251
# 13243   Juliana, a fifteen-year old girl, moves with ...                 251
# 10895   Rebekah follows the story of Isaac through th...                 251
# 12925   Jack Squire is a Currency Trader on assignmen...                 251
# 13221   While Hamish Macbeth is on duty temporarily i...                 252
#
#                                        clean_Description
# 6549    The Doctor and his companions, separated from...
# 13243   Juliana, a fifteen-year old girl, moves with ...
# 10895   Rebekah follows the story of Isaac through th...
# 12925   Jack Squire is a Currency Trader on assignmen...
# 13221   While Hamish Macbeth is on duty temporarily i...

# %% [markdown]
# #NPL Componet(text summarization)

# %% [markdown]
# #Deep learning method

# %%
from transformers import BartTokenizer, BartForConditionalGeneration

# %%
# Load model and tokenizer
model = BartForConditionalGeneration.from_pretrained('facebook/bart-large-cnn')
tokenizer = BartTokenizer.from_pretrained('facebook/bart-large-cnn')
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.58k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %%
model.to('cuda')

# %%
def add_summarize(text):
  text=str("summarize: " + text)
  return text

batch_size=256
data_numbers=len(data_frame_cleaned)
process_num=math.ceil(data_numbers/batch_size)


output_path='/content/drive/MyDrive/output_path.csv'
output_dict={'name':[],'summary':[]}


for i in range(process_num):
  #put data in a batch
  texts=list(data_frame_cleaned.iloc[batch_size*i:(i+1)*batch_size]['Description'].apply(add_summarize))

  #set min length of summary
  maxs=max(list(data_frame_cleaned.iloc[batch_size*i:(i+1)*batch_size]['len_of_Description']))
  mins=min(list(data_frame_cleaned.iloc[batch_size*i:(i+1)*batch_size]['len_of_Description']))
  min_len=min(500,int(0.2*mins))


  # Encode the text and generate summary
  inputs = tokenizer(texts, return_tensors="pt", max_length=maxs, padding="longest", truncation=True)
  #inputs = {k: v.cuda() for k, v in inputs.items()}
  input_x=inputs['input_ids'].cuda()



  # # Generate summaries
  summary_ids = model.generate(input_x, max_length=maxs, min_length=min_len, length_penalty=2.0, num_beams=4, early_stopping=True)
  summaries = [tokenizer.decode(g, skip_special_tokens=True) for g in summary_ids]

  #save the output
  output_dict['name'].extend(list(data_frame_cleaned.iloc[batch_size*i:(i+1)*batch_size]['Title']))
  output_dict['summary'].extend(summaries)
  temp_output=pd.DataFrame(output_dict)
  temp_output.to_csv(output_path)

  print(i)

# %% [markdown]
# #extrctive method

# %%
# !pip install sumy

# %%
from sumy.parsers.plaintext import PlaintextParser
from sumy.nlp.tokenizers import Tokenizer
from sumy.summarizers.lsa import LsaSummarizer
import nltk
nltk.download('punkt')
import numpy as np
from nltk.tokenize import word_tokenize, sent_tokenize
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
def sentence_tokenizer(data):
  sentences = sent_tokenize(data)
  return sentences

# %%
data_frame_cleaned['sentences_of_Description']=data_frame_cleaned['clean_Description'].apply(sentence_tokenizer)
data_frame_cleaned['sentences_number_of_Description']=data_frame_cleaned['sentences_of_Description'].apply(len)

# %%
data_frame_cleaned.head()
# Out:
#              ID         Tag                  Title  \
# 6549    5408961   /m/0dkk4_                 Zamper
# 13243  20297155  /m/04zxt3s      Blackthorn Winter
# 10895  13733151  /m/03cgkpf                Rebekah
# 12925  19433109  /m/04n2tm1  Vaporetto 13: A Novel
# 13221  20258594  /m/04zwxmp   Death of an Outsider
#
#                                              Description  len_of_Description  \
# 6549    The Doctor and his companions, separated from...                 251
# 13243   Juliana, a fifteen-year old girl, moves with ...                 251
# 10895   Rebekah follows the story of Isaac through th...                 251
# 12925   Jack Squire is a Currency Trader on assignmen...                 251
# 13221   While Hamish Macbeth is on duty temporarily i...                 252
#
#                                        clean_Description  \
# 6549    The Doctor and his companions, separated from...
# 13243   Juliana, a fifteen-year old girl, moves with ...
# 10895   Rebekah follows the story of Isaac through th...
# 12925   Jack Squire is a Currency Trader on assignmen...
# 13221   While Hamish Macbeth is on duty temporarily i...
#
#                                 sentences_of_Description  \
# 6549   [ The Doctor and his companions, separated fro...
# 13243  [ Juliana, a fifteen-year old girl, moves with...
# 10895  [ Rebekah follows the story of Isaac through t...
# 12925  [ Jack Squire is a Currency Trader on assignme...
# 13221  [ While Hamish Macbeth is on duty temporarily ...
#
#        sentences_number_of_Description
# 6549                                 3
# 13243                                2
# 10895                                3
# 12925                                2
# 13221                                2

# %%
def summarize(text, language="english", sentences_count=5):
    parser = PlaintextParser.from_string(text, Tokenizer(language))
    summarizer = LsaSummarizer()
    summary = summarizer(parser.document, sentences_count)
    return ' '.join([str(sentence) for sentence in summary])

# %%
output_dict={'title':[],'summary':[]}
for sentences_number_of_Description,title,Description in zip(data_frame_cleaned['sentences_number_of_Description'],data_frame_cleaned['Title'],data_frame_cleaned['clean_Description']):
    sentences_count=int(0.7*sentences_number_of_Description)
    summary=summarize(Description,"english",sentences_count)
    output_dict['title'].append(title)
    output_dict['summary'].append(summary)

# %%
#save the output
output_path='/content/drive/MyDrive/Condensed_Description.csv'
temp_output=pd.DataFrame(output_dict)
temp_output.to_csv(output_path)

# %%
temp_output.head()
# Out:
#                    title                                            summary
# 0                 Zamper  It is an organization dedicated to building gi...
# 1      Blackthorn Winter  Juliana, a fifteen-year old girl, moves with h...
# 2                Rebekah  Rebekah follows the story of Isaac through the...
# 3  Vaporetto 13: A Novel  Major characters include Jack Squire, currency...
# 4   Death of an Outsider  No one wants to solve the crime, including Mac...

# %% [markdown]
# #text2image

# %%
import cv2
import math
import nltk
import numpy as np
nltk.download('punkt')
from nltk.tokenize import word_tokenize, sent_tokenize
import  matplotlib.pyplot as plt
import os
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
def text2image(text='',word_per_line=20,pixel_per_word=200,h_padding=100,v_padding=150,img_path=''):

    words=word_tokenize(text)
    number_of_line=math.ceil(len(words)/word_per_line)

    raw_image=np.ones(((v_padding*(number_of_line+1),(pixel_per_word*word_per_line)+(1*h_padding))))*255

    font = cv2.FONT_HERSHEY_SIMPLEX
    fontScale = 2
    color = 0
    thickness = 2

    for i in range(number_of_line):
      temp_text=words[i*word_per_line]
      for x in words[(i*word_per_line)+1:(i+1)*word_per_line]:
         temp_text+=(' '+x)
      raw_image= cv2.putText(raw_image, temp_text, (h_padding,v_padding*(i+1)), font,fontScale, color, thickness, cv2.LINE_AA)

    cv2.imwrite(img_path,raw_image)

# %%
for title ,summary in zip(temp_output['title'],temp_output['summary']):
  img_path=os.path.join('/content/drive/MyDrive/images',title+'_img.jpg')
  text2image(text=summary,word_per_line=20,pixel_per_word=200,h_padding=100,v_padding=150,img_path=img_path)
